# %%
import numpy as np
arr = np.array([10, 5, 20, 8, 25, 3])
top_n = np.sort(arr)[-3]
print("Top 3:", top_n)
# Out:
# Top 3: 10

# %%
import numpy as np
A = np.array([[4, 2],[1, 3]])
det = np.linalg.det(A)
eigenvalues, eigenvectors = np.linalg.eig(A)
print("Matrix: \n",A)
print("Determinant: \n",det)
print("Eigenvalues:", eigenvalues)
print("Eigenvectors:",eigenvectors)
# Out:
# Matrix:
#  [[4 2]
#  [1 3]]
# Determinant:
#  10.000000000000002
# Eigenvalues: [5. 2.]
# Eigenvectors: [[ 0.89442719 -0.70710678]
#  [ 0.4472136   0.70710678]]
